# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Read Data from CSV

# %% [markdown]
#  READ DATA FROM DATASET

# %%
cars_data = pd.read_csv('CarPrice_Assignment.csv')

# %%
cars_data.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %%
cars_data.drop('car_ID',axis=1,inplace=True)

# %%
cars_data
# Out:
#      symboling                   CarName fueltype aspiration doornumber  \
# 0            3        alfa-romero giulia      gas        std        two
# 1            3       alfa-romero stelvio      gas        std        two
# 2            1  alfa-romero Quadrifoglio      gas        std        two
# 3            2               audi 100 ls      gas        std       four
# 4            2                audi 100ls      gas        std       four
# ..         ...                       ...      ...        ...        ...
# 200         -1           volvo 145e (sw)      gas        std       four
# 201         -1               volvo 144ea      gas      turbo       four
# 202         -1               volvo 244dl      gas        std       four
# 203         -1                 volvo 246   diesel      turbo       four
# 204         -1               volvo 264gl      gas      turbo       four
#
#          carbody drivewheel enginelocation  wheelbase  carlength  ...  \
# ...

# %% [markdown]
# # Data analysis

# %% [markdown]
# GET DETAILS ABOUT THE DATASET

# %%
cars_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   symboling         205 non-null    int64
#  1   CarName           205 non-null    object
#  2   fueltype          205 non-null    object
#  3   aspiration        205 non-null    object
#  4   doornumber        205 non-null    object
#  5   carbody           205 non-null    object
#  6   drivewheel        205 non-null    object
#  7   enginelocation    205 non-null    object
#  8   wheelbase         205 non-null    float64
#  9   carlength         205 non-null    float64
#  10  carwidth          205 non-null    float64
#  11  carheight         205 non-null    float64
#  12  curbweight        205 non-null    int64
#  13  enginetype        205 non-null    object
#  14  cylindernumber    205 non-null    object
#  15  enginesize        205 non-null    int64
# ...

# %% [markdown]
# THE TOTAL ROWS ARE 205
# WITH 24 ATTRIBUTES CONTAINING CRITICAL INFORMATION ABOUT CARS

# %%
# HERE WE CHECK FOR ANY NULL (NAN) VALUES IN THE DATASET

cars_data.isnull().sum()
# Out:
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %% [markdown]
# THERE ARE NO EMPTY VALUES IN THIS GIVEN DATASET

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# WE NEED TO CHECK THE DATASET FOR ANY OUTLIERS
#
# WE CAN DO THIS BY USING THE BOXPLOT GRAPH WHICH SHOWS ANY OUTLIER VALUES

# %%
sns.boxplot(cars_data["price"],orient='horizontal')
# Out:
# <Axes: >

# %% [markdown]
# WE NOW REMOVE SOME OUTLIERS WHICH CAN BEEN SEEN ON THE RIGHTMOST SIDE OF THIS GRAPH

# %%
#removing Outliers

q1 = cars_data['price'].quantile(0.25)
q2 = cars_data['price'].quantile(0.75)
InterquantileRange = q2-q1

# %% [markdown]
# WE CAN REMOVE THE OUTLIERS BY TAKING THE INTERQUANTILE RANGE OF THIS DATASET

# %%
upper_limit = q2+1.5*InterquantileRange
lower_limit = q1-1.5*InterquantileRange

# %%
def preprocess(value):
    if value>=upper_limit:
        return False
    if value<=lower_limit:
        return False
    else:
        return True

# %%
cars_data = cars_data[df]

# %%
cars_data
# Out:
#      symboling                   CarName fueltype aspiration doornumber  \
# 0            3        alfa-romero giulia      gas        std        two
# 1            3       alfa-romero stelvio      gas        std        two
# 2            1  alfa-romero Quadrifoglio      gas        std        two
# 3            2               audi 100 ls      gas        std       four
# 4            2                audi 100ls      gas        std       four
# ..         ...                       ...      ...        ...        ...
# 200         -1           volvo 145e (sw)      gas        std       four
# 201         -1               volvo 144ea      gas      turbo       four
# 202         -1               volvo 244dl      gas        std       four
# 203         -1                 volvo 246   diesel      turbo       four
# 204         -1               volvo 264gl      gas      turbo       four
#
#          carbody drivewheel enginelocation  wheelbase  carlength  ...  \
# ...

# %% [markdown]
# # Encoding Categorical Coloums

# %%
cars_data.head(1)
# Out:
#    symboling             CarName fueltype aspiration doornumber      carbody  \
# 0          3  alfa-romero giulia      gas        std        two  convertible
#
#   drivewheel enginelocation  wheelbase  carlength  ...  enginesize  \
# 0        rwd          front       88.6      168.8  ...         130
#
#    fuelsystem  boreratio stroke compressionratio  horsepower peakrpm  citympg  \
# 0        mpfi       3.47   2.68              9.0         111    5000       21
#
#    highwaympg    price
# 0          27  13495.0
#
# [1 rows x 25 columns]

# %%
cars_data['fueltype'] = cars_data['fueltype'].map({'gas':0,'diesel':1})
cars_data['aspiration'] = cars_data['aspiration'].map({'std':0,'turbo':1})
cars_data['doornumber'] = cars_data['doornumber'].map({'two':2,'four':4})
cars_data['carbody'] = cars_data['carbody'].map({'convertible':0,'hatchback':1,'sedan':2,'wagon':3,'hardtop':4,})
cars_data['drivewheel'] = cars_data['drivewheel'].map({'rwd':0,'fwd':1,'4wd':2})
cars_data['enginetype'] = cars_data['enginetype'].map({'dohc':0,'ohcv':1,'ohc':2,'l':3,'rotor':4,'ohcf':5})
cars_data['cylindernumber'] = cars_data['cylindernumber'].map({'four':4,'six':6,'five':5,'three':3,'two':2})
cars_data['fuelsystem'] = cars_data['fuelsystem'].map({'mpfi':0,'2bbl':1,'mfi':2,'1bbl':3,'spfi':4,'4bbl':5,'idi':6,'spdi':7,})
# Out:
# C:\Users\Kanhaiya\AppData\Local\Temp\ipykernel_3696\3460652248.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cars_data['fueltype'] = cars_data['fueltype'].map({'gas':0,'diesel':1})

# %%
cars_data['enginelocation'].unique()
# Out:
# array(['four', 'six', 'five', 'three', 'two'], dtype=object)

# %% [markdown]
# enginelocation has only one value.. hence this attribute has no influence in car pricing

# %%
cars_data.drop('enginelocation',inplace=True,axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[113], line 1
# ----> 1 cars_data.drop('enginelocation',inplace=True,axis=1)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5251 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5252 def drop(  # type: ignore[override]
#    5253     self,
#    (...)
# ...

# %% [markdown]
# # Prepping for training

# %%
#features matrix in X and Target Variable(Price) in Y
X = cars_data.drop(['CarName','price'],axis=1)
Y = cars_data['price']

# %%
Y
# Out:
# 0      13495.0
# 1      16500.0
# 2      16500.0
# 3      13950.0
# 4      17450.0
#         ...
# 200    16845.0
# 201    19045.0
# 202    21485.0
# 203    22470.0
# 204    22625.0
# Name: price, Length: 190, dtype: float64

# %% [markdown]
# SINCE WE HAVE TO PREDICT CONTINUOS NUMERICAL DATA, REGRESSION IS THE APPROPRIATE METHOD FOR THIS

# %%
#splitting into Train and Test dataset
trainX,testX,trainY,testY=train_test_split(X,Y,test_size=0.20,random_state=20)

# %% [markdown]
# # Import Models

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor

# %% [markdown]
# # Training Data on Multiple Regression Algorithms

# %%
lr = LinearRegression()
rf = RandomForestRegressor()
xgb = GradientBoostingRegressor()
lr.fit(trainX,trainY)
rf.fit(trainX,trainY)
xgb.fit(trainX,trainY)
# Out:
# GradientBoostingRegressor()

# %%
pred_lf = lr.predict(testX)
pred_rf = rf.predict(testX)
pred_xgb = xgb.predict(testX)

# %% [markdown]
# # Evaluating the Algorithm

# %%
from sklearn import metrics

# %%
score_lf = metrics.r2_score(testY,pred_lf)
score_rf = metrics.r2_score(testY,pred_rf)
score_xgb = metrics.r2_score(testY,pred_xgb)

MAE_lf = metrics.mean_squared_error(testY,pred_lf)
MAE_rf = metrics.mean_squared_error(testY,pred_rf)
MAE_xgb = metrics.mean_squared_error(testY,pred_xgb)

# %%
algorithms = pd.DataFrame({
    'Models':['LR','RF','XGB'],
    'R2_SCORE':[score_lf,score_rf,score_xgb],
    'Mean Squared Error':[MAE_lf,MAE_rf,MAE_xgb]
})

# %%
algorithms
# Out:
#   Models  R2_SCORE  Mean Squared Error
# 0     LR  0.794104        5.322036e+06
# 1     RF  0.859479        3.632210e+06
# 2    XGB  0.885157        2.968483e+06

# %%
sns.barplot(x=algorithms['Models'],y=algorithms['R2_SCORE']).set(title='R2 Score')
# Out:
# [Text(0.5, 1.0, 'R2 Score')]

# %% [markdown]
# THE R2 SCORE IS A VERY IMPORTANT METRIC FOR EVALUATING REGRESSION MODELS.
#
# THE HIGHER THE R2 SCORE , THE BETTER THE MODEL AT PREDICTION
#
# IN THIS CASE, THE XGB MODEL HAS THE HIGHEST SCORE

# %%
sns.barplot(x=algorithms['Models'],y=algorithms['Mean Squared Error']).set(title='Mean Squared Error')
# Out:
# [Text(0.5, 1.0, 'Mean Squared Error')]

# %% [markdown]
# As we can Observe, the XGB Algorithm has the best prediction among the other algorithms

# %%
xgb.score(testX,pred_xgb)
# Out:
# 1.0

# %% [markdown]
# We have successfully created a car Price Prediction Model
